# %% [markdown]
# ## We choose a window of 60 time steps
# ## We want to learn 48 steps and predict 12 steps.
# ## Each step = 1 second

# %%
import sys
sys.path.append('../')

import pandas as pd
import numpy as np
import keras
from datetime import datetime, timedelta
from sklearn.preprocessing import StandardScaler
from configs.utils_2 import windowing, windowing_array
from sklearn.model_selection import train_test_split
from configs.utils_2 import split_sequence, split_sequence_long
import math

# %load_ext autoreload
# %autoreload 2
# Out:
# 2024-04-04 12:37:52.398686: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-04 12:37:52.425878: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-04 12:37:52.425905: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-04 12:37:52.426694: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-04 12:37:52.431406: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-04 12:37:52.928194: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Data Exploration

# %%
csv_input = pd.read_csv('../data/files/dataset_trajectory.csv')
data = csv_input

# %%
# show head
print(data.shape)
data.head()
# Out:
# (4597200, 6)
#        pos.x     pos.y     pos.z   heading  velocity  weather
# 0 -77.030670 -1.283448  0.294200 -1.568362  7.056001        2
# 1 -77.030670 -1.283448  0.061311 -1.568362  7.172558        2
# 2 -77.029778 -1.283539 -0.030319 -1.568443  1.053028        2
# 3 -77.028854 -1.283728 -0.023681 -1.568593  0.883579        2
# 4 -77.008575 -1.288779  0.003869 -1.572756  1.548891        2

# %%
# Remove rows with any NaN values
data = data.dropna()
print(len(data))
# Out:
# 4597200

# %% [markdown]
# ### Time

# %%
## Adding date time
# Start datetime
start_datetime = datetime(2009, 1, 1, 0, 0, 0)

# Generate datetime column with incrementing seconds
num_rows = len(data)
seconds_increment = timedelta(seconds=1)

date_times = [start_datetime + i * seconds_increment for i in range(num_rows)]

# Add datetime column to DataFrame
data['Date Time'] = date_times

# %%
date_time = pd.to_datetime(data.pop('Date Time'), format='%d.%m.%Y %H:%M:%S')
timestamp_s = date_time.map(pd.Timestamp.timestamp)
minute = 60
data['Minute sin'] = np.sin(timestamp_s * (2 * np.pi / minute))
data['Minute cos'] = np.cos(timestamp_s * (2 * np.pi / minute))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4597200 entries, 0 to 4597199
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   pos.x       float64
#  1   pos.y       float64
#  2   pos.z       float64
#  3   heading     float64
#  4   velocity    float64
#  5   weather     int64
#  6   Minute sin  float64
#  7   Minute cos  float64
# dtypes: float64(7), int64(1)
# memory usage: 280.6 MB

# %%
data.head()
# Out:
#        pos.x     pos.y     pos.z   heading  velocity  weather    Minute sin  \
# 0 -77.030670 -1.283448  0.294200 -1.568362  7.056001        2 -1.792514e-08
# 1 -77.030670 -1.283448  0.061311 -1.568362  7.172558        2  1.045284e-01
# 2 -77.029778 -1.283539 -0.030319 -1.568443  1.053028        2  2.079117e-01
# 3 -77.028854 -1.283728 -0.023681 -1.568593  0.883579        2  3.090170e-01
# 4 -77.008575 -1.288779  0.003869 -1.572756  1.548891        2  4.067366e-01
#
#    Minute cos
# 0    1.000000
# 1    0.994522
# 2    0.978148
# 3    0.951057
# 4    0.913545

# %% [markdown]
# ### Windowing
# We choose a window of 10 time steps
# We want to learn 8 steps and predict 2 steps.

# %%
window_size = 60
grouped_data = windowing_array(data, window_size)

# %%
print(len(grouped_data))
print(len(grouped_data[0]))
print(len(grouped_data[0][0]))
# Out:
# 76620
# 60
# 8

# %% [markdown]
# ### Slice and Split sequence

# %%
x_train_init, x_test_init = train_test_split(grouped_data, shuffle=False, test_size=0.2)

# %%
x_train_init.shape, x_test_init.shape
# Out:
# ((61296, 60, 8), (15324, 60, 8))

# %%
## slipt x_train_init to x_train, y_train, y_train_shifted_by_one

x_train, y_train, y_train_shifted_by_one = split_sequence_long(x_train_init)

# %%
x_train.shape, y_train.shape
# Out:
# ((61296, 48, 8), (61296, 12, 8))

# %%
x_train.shape[0], x_train.shape[1], x_train.shape[2]
# Out:
# (61296, 48, 8)

# %%
## First Let's start with predict only one input
#y_train = y_train[:,:,:1]

## Now let's try to predict two inputs (posx and posy)
y_train = y_train[:,:,:2]

# %%
y_train.shape
# Out:
# (61296, 12, 2)

# %%
## slipt x_test_init to y_test, y_test_shift_by_one, y_test
x_test, y_test, y_test_shifted_by_one = split_sequence_long(x_test_init)

# %%
x_test.shape, y_test.shape
# Out:
# ((15324, 48, 8), (15324, 12, 8))

# %%
## First Let's start with predict only one input
#y_test = y_test[:,:,:1]

## Now let's try to predict two inputs (posx and posy)
y_test = y_test[:,:,:2]

# %%
y_test.shape
# Out:
# (15324, 12, 2)

# %% [markdown]
# ### Model Configuration

# %%
# Define the input shape
input_shape = x_train.shape[1:]
input_shape
# Out:
# (48, 8)

# %%
# Define the output shape
outout_shape = y_train.shape[1:]
outout_shape
# Out:
# (12, 2)

# %%
# Define the output vector size
y_train_feature_nr = len(y_train[1])
output_seq_size = 2
output_features_vector=y_train_feature_nr * output_seq_size
output_features_vector
# Out:
# 24

# %% [markdown]
# ### Train and evaluate

# %%
from models.transformer import ITPF_Transformer


model = ITPF_Transformer()

# %%
model = model.build_model(
    input_shape=input_shape, 
    output_shape=outout_shape,
    output_features_vector=output_features_vector, 
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25
)

# %%
epochs = 30
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model_long_2.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss=["mse"],
    metrics=['mae'],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/30
# 1533/1533 [==============================] - 109s 69ms/step - loss: 911.1534 - mae: 19.7636 - val_loss: 239.7258 - val_mae: 8.9241 - lr: 0.0010
# Epoch 2/30
# 1533/1533 [==============================] - 95s 62ms/step - loss: 448.5004 - mae: 14.8846 - val_loss: 225.2432 - val_mae: 8.3801 - lr: 0.0010
# Epoch 3/30
# 1533/1533 [==============================] - 95s 62ms/step - loss: 429.8104 - mae: 14.5656 - val_loss: 235.1615 - val_mae: 9.3496 - lr: 0.0010
# Epoch 4/30
# 1533/1533 [==============================] - 95s 62ms/step - loss: 425.5931 - mae: 14.5071 - val_loss: 216.8026 - val_mae: 8.5432 - lr: 0.0010
# Epoch 5/30
# 1533/1533 [==============================] - 95s 62ms/step - loss: 420.7224 - mae: 14.4232 - val_loss: 209.8622 - val_mae: 8.4827 - lr: 0.0010
# Epoch 6/30
# Epoch 24/30
# 1533/1533 [==============================] - 95s 62ms/step - loss: 302.2442 - mae: 12.6784 - val_loss: 250.0469 - val_mae: 10.3555 - lr: 0.0010
# Epoch 25/30
# 1533/1533 [==============================] - 96s 62ms/step - loss: 303.8026 - mae: 12.6921 - val_loss: 411.0258 - val_mae: 13.6445 - lr: 0.0010
# Epoch 26/30
# 1533/1533 [==============================] - 109s 71ms/step - loss: 299.1536 - mae: 12.6075 - val_loss: 263.7216 - val_mae: 10.5503 - lr: 0.0010
# Epoch 27/30
# 1533/1533 [==============================] - 117s 76ms/step - loss: 302.5530 - mae: 12.6727 - val_loss: 261.3268 - val_mae: 9.9318 - lr: 0.0010
# Epoch 28/30
# 1533/1533 [==============================] - 127s 83ms/step - loss: 295.6035 - mae: 12.5490 - val_loss: 203.7430 - val_mae: 8.2478 - lr: 0.0010
# Epoch 29/30
# 1533/1533 [==============================] - 127s 83ms/step - loss: 283.2526 - mae: 12.2629 - val_loss: 281.3485 - val_mae: 10.0636 - lr: 5.0000e-04
# Epoch 30/30
# 1533/1533 [==============================] - 122s 80ms/step - loss: 282.1544 - mae: 12.2434 - val_loss: 237.1272 - val_mae: 9.0891 - lr: 5.0000e-04

# %%
#model.summary()

# %%
model = keras.models.load_model("best_model_long_2.keras")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 479/479 [==============================] - 9s 18ms/step - loss: 169.5780 - mae: 7.7467
# Test accuracy 7.746744155883789
# Test loss 169.57801818847656

# %%
import matplotlib.pyplot as plt

metric = "mae"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
predictions = model.predict(x_test)
# Out:
# 479/479 [==============================] - 9s 18ms/step

# %%
predictions.shape
# Out:
# (15324, 12, 2)

# %%
import random
from configs.utils_2 import plot_pred, plot_pred2


print("Visualize some few predictions")

# After finding the best prediction, visualize it
if x_test is not None and y_test is not None and predictions is not None:
    # This visualization will now only show the best prediction example
    for item in range(0, 10):
        index = random.randint(0, len(x_test[:, :, :2]))
        plot_pred2(x_test[:, :, :2][index], y_test[index], predictions[index])
# Out:
# Visualize some few predictions

# %% [markdown]
# ## Explainer

# %%
from explainers.explainer import BlackBoxWrapper, ITPFExplainer

blackbox = BlackBoxWrapper(model=model, isMultivariate=True)
explainer = ITPFExplainer()
explainer.fit_exp(model=blackbox, x=x_train, y=y_train, feature_names=["pos.x", "pos.y", "pos.z", "heading", "velocity", "weather", "Minute sin", "Minute cos"], class_names=['pos.x', 'pos.y'])

# %% [markdown]
# ### LIME

# %%
explainer.lime(y=x_test[0], labelId=0)
# Out:
# (5000, 48, 8)
# 157/157 [==============================] - 3s 18ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 explainer.lime(y=x_test[0], labelId=0)
#
# File ~/Thesis/Simple_Multivariate_Transformer/forecast/notebooks/../explainers/explainer.py:138, in ITPFExplainer.lime(self, y, labelId)
#     129 explainer = lime_tabular.RecurrentTabularExplainer(
#     130     training_data=self.data_x,
#     131     training_labels=self.data_y,
#    (...)
#     135     discretizer='decile'
#     136 )
#     137 # Get the the result
# --> 138 exp = explainer.explain_instance(y, self.model.predict_for_lime, num_features=10, labels=(labelId,))
#     139 exp.show_in_notebook()
#
# File ~/.local/lib/python3.10/site-packages/lime/lime_tabular.py:695, in RecurrentTabularExplainer.explain_instance(self, data_row, classifier_fn, labels, top_labels, num_features, num_samples, distance_metric, model_regressor)
#     693 # Wrap the classifier to reshape input
#     694 classifier_fn = self._make_predict_proba(classifier_fn)
# --> 695 return super(RecurrentTabularExplainer, self).explain_instance(
#     696     data_row, classifier_fn,
#     697     labels=labels,
#     698     top_labels=top_labels,
#     699     num_features=num_features,
#     700     num_samples=num_samples,
#     701     distance_metric=distance_metric,
#     702     model_regressor=model_regressor)
#
# File ~/.local/lib/python3.10/site-packages/lime/lime_tabular.py:379, in LimeTabularExplainer.explain_instance(self, data_row, predict_fn, labels, top_labels, num_features, num_samples, distance_metric, model_regressor)
#     372             warnings.warn("""
#     373             Prediction probabilties do not sum to 1, and
#     374             thus does not constitute a probability space.
#     375             Check that you classifier outputs probabilities
#     376             (Not log probabilities, or actual class predictions).
#     377             """)
#     378     else:
# --> 379         raise ValueError("Your model outputs "
#     380                          "arrays with {} dimensions".format(len(yss.shape)))
#     382 # for regression, the output should be a one-dimensional array of predictions
#     383 else:
#     384     try:
#
# ValueError: Your model outputs arrays with 3 dimensions

# %% [markdown]
# ### Shap

# %%
explainer.shap(x_test[0])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# 2/2 [==============================] - 0s 6ms/step
#   0%|          | 0/48 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 18ms/step
# 189/189 [==============================] - 1s 4ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 explainer.shap(x_test[0])
#
# File ~/Thesis/Simple_Multivariate_Transformer/forecast/notebooks/../explainers/explainer.py:156, in ITPFExplainer.shap(self, y)
#     154 explainer = shap.KernelExplainer(model=self.model.predict_for_shap, data=self.data_x[0], feature_names=self.feature_names)
#     155 # Get shap values
# --> 156 shap_values = explainer.shap_values(y)
#     157 shap.summary_plot(shap_values, y)
#
# File ~/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:244, in KernelExplainer.shap_values(self, X, **kwargs)
#     242 if self.keep_index:
#     243     data = convert_to_instance_with_index(data, column_name, index_value[i:i + 1], index_name)
# --> 244 explanations.append(self.explain(data, **kwargs))
#     245 if kwargs.get("gc_collect", False):
#     246     gc.collect()
#
# File ~/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:442, in KernelExplainer.explain(self, incoming_instance, **kwargs)
#     439     self.kernelWeights[nfixed_samples:] *= weight_left / self.kernelWeights[nfixed_samples:].sum()
#     441 # execute the model on the synthetic samples we have created
# --> 442 self.run()
#     444 # solve then expand the feature importance (Shapley value) vector to contain the non-varying features
#     445 phi = np.zeros((self.data.groups_size, self.D))
#
# File ~/.local/lib/python3.10/site-packages/shap/explainers/_kernel.py:584, in KernelExplainer.run(self)
#     582 if isinstance(modelOut, (pd.DataFrame, pd.Series)):
#     583     modelOut = modelOut.values
# --> 584 self.y[self.nsamplesRun * self.N:self.nsamplesAdded * self.N, :] = np.reshape(modelOut, (num_to_run, self.D))
#     586 # find the expected value of each output
#     587 for i in range(self.nsamplesRun, self.nsamplesAdded):
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:285, in reshape(a, newshape, order)
#     200 @array_function_dispatch(_reshape_dispatcher)
#     201 def reshape(a, newshape, order='C'):
#     202     """
#     203     Gives a new shape to an array without changing its data.
#     204
#    (...)
#     283            [5, 6]])
#     284     """
# --> 285     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: cannot reshape array of size 145152 into shape (6048,12)
